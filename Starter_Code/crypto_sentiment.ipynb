# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi import NewsApiClient
from pathlib import Path
# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\Straw
# [nltk_data]     Hat\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Create a newsapi client
from newsapi import NewsApiClient
load_dotenv()
newsapi = NewsApiClient(api_key=os.environ["NEWS_API_KEY"])

# %%
# Fetch the Bitcoin news articles
bitcoin_headlines = newsapi.get_everything(
    q="bitcoin",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# %%
# Fetch the Ethereum news articles
ethereum_headlines= newsapi.get_everything(
    q="Ethereum",
    language="en", 
    sort_by='relevancy',
)

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in bitcoin_headlines["articles"]:
    try:
        
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            
            
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu,
            "Text": text
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["Compound", "Positive", "Negative", "Neutral","Text"]
bitcoin_df = bitcoin_df[cols]

bitcoin_df.head(10)
# Out:
#    Compound  Positive  Negative  Neutral  \
# 0    0.5859     0.124     0.000    0.876
# 1    0.0000     0.000     0.000    1.000
# 2    0.3182     0.105     0.000    0.895
# 3   -0.4404     0.000     0.083    0.917
# 4   -0.3182     0.045     0.084    0.871
# 5    0.0000     0.000     0.000    1.000
# 6   -0.7096     0.000     0.169    0.831
# 7    0.3612     0.068     0.000    0.932
# 8   -0.4404     0.000     0.083    0.917
# 9    0.3818     0.073     0.000    0.927
#
#                                                 Text
# 0  Even if you arent paying attention to Bitcoin ...
# 1  When Denis Rusinovich set up cryptocurrency mi...
# 2  El Salvador introduced Bitcoin as a legal tend...
# 3  Were officially building an open Bitcoin minin...
# 4  Israeli national Tal Prihar pled guilty to rou...
# 5  In a new blog post the company said that 4,836...
# 6  Netflix\r\n is making a docuseries about one o...
# 7  Bitcoin, the largest digital asset, extended i...
# 8  Block founder Jack Dorsey has announced on Twi...
# 9  Tesla Inc (TSLA.O) will accept the meme-based ...

# %%
# Create the Ethereum sentiment scores DataFrame
ethereum_sentiments = []

for article in ethereum_headlines["articles"]:
    try:
        
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            
            
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu,
            "Text": text
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["Compound", "Positive", "Negative", "Neutral","Text"]
ethereum_df = ethereum_df[cols]

ethereum_df.head(10)
# Out:
#    Compound  Positive  Negative  Neutral  \
# 0    0.0000     0.000     0.000    1.000
# 1    0.0000     0.000     0.000    1.000
# 2    0.1779     0.052     0.000    0.948
# 3    0.0772     0.038     0.000    0.962
# 4   -0.2023     0.039     0.062    0.899
# 5    0.0000     0.000     0.000    1.000
# 6   -0.1027     0.056     0.067    0.877
# 7    0.0000     0.000     0.000    1.000
# 8    0.4019     0.085     0.000    0.915
# 9   -0.0557     0.041     0.047    0.911
#
#                                                 Text
# 0  In a new blog post the company said that 4,836...
# 1  Hackers who made off with roughly $15 million ...
# 2  On some level, the new mayor is simply employi...
# 3  Back in September\r\n, Robinhood announced pla...
# 4  If people who buy cryptocurrencies intended on...
# 5  This enables an L1 platform to bootstrap its n...
# 6  Trading platform Crypto.com lost about $34 mil...
# 7  The means-and-ends moralists, or non-doers, al...
# 8  Ethereum is a digital platform that runs on bl...
# 9  Crypto bros never tire of sharing their utopia...

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#          Compound    Positive    Negative     Neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.073527    0.069430    0.047950    0.882590
# std      0.428141    0.062734    0.064763    0.083741
# min     -0.817600    0.000000    0.000000    0.662000
# 25%     -0.288875    0.000000    0.000000    0.831000
# 50%      0.064400    0.070000    0.000000    0.895000
# 75%      0.445000    0.112750    0.088000    0.937250
# max      0.834100    0.234000    0.258000    1.000000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#         Compound   Positive   Negative    Neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.095105   0.053250   0.022100   0.924650
# std     0.297967   0.054394   0.045603   0.074845
# min    -0.680800   0.000000   0.000000   0.775000
# 25%     0.000000   0.000000   0.000000   0.889750
# 50%     0.000000   0.043500   0.000000   0.931500
# 75%     0.233900   0.090250   0.011750   1.000000
# max     0.680800   0.185000   0.174000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin
#
# Q: Which coin had the highest compound score?
#
# A: Bitcoin
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Expand the default stopwords list if necessary
sw = set(stopwords.words('english'))

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    
    regex = re.compile("[^a-zA-Z ]")
   
    # Create a tokenized list of the words
    re_clean = regex.sub('', text)
    words = word_tokenize(re_clean)
    words = word_tokenize(re_clean)
    words = word_tokenize(re_clean.lower())
    
    # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
   
    # Convert the words to lowercase
    words = [word for word in words if word not in sw]
    
    # Remove the stop words
   
    return lem

tokenizer(bitcoin_df.iloc[0]['Text'])
# Out:
# ['even',
#  'if',
#  'you',
#  'arent',
#  'paying',
#  'attention',
#  'to',
#  'bitcoin',
#  'and',
#  'other',
#  'cryptocurrencies',
#  'you',
#  'might',
#  'have',
#  'noticed',
#  'that',
#  'their',
#  'value',
#  'plummeted',
#  'last',
#  'week',
#  'with',
#  'the',
#  'total',
#  'value',
#  'of',
#  'the',
#  'market',
#  'tumbling',
#  'from',
#  'a',
#  'high',
#  'of',
#  'tr',
#  'char']

# %%
# Create a new tokens column for Bitcoin
bitcoin_df['tokens'] = bitcoin_df['Text'].apply(tokenizer)
bitcoin_df
# Out:
#     Compound  Positive  Negative  Neutral  \
# 0     0.5859     0.124     0.000    0.876
# 1     0.0000     0.000     0.000    1.000
# 2     0.3182     0.105     0.000    0.895
# 3    -0.4404     0.000     0.083    0.917
# 4    -0.3182     0.045     0.084    0.871
# ..       ...       ...       ...      ...
# 95    0.0516     0.061     0.056    0.882
# 96    0.6124     0.147     0.000    0.853
# 97   -0.0772     0.081     0.088    0.831
# 98    0.4404     0.077     0.000    0.923
# 99    0.0000     0.000     0.000    1.000
#
#                                                  Text  \
# 0   Even if you arent paying attention to Bitcoin ...
# 1   When Denis Rusinovich set up cryptocurrency mi...
# 2   El Salvador introduced Bitcoin as a legal tend...
# 3   Were officially building an open Bitcoin minin...
# 4   Israeli national Tal Prihar pled guilty to rou...
# ..                                                ...
# 95  Quantum computers would need to become around ...
# 96  US stock futures slipped Monday after the majo...
# 97  Anna Moneymaker/GettyOn Sept. 4, 2017, accordi...
# 98  ProFootball Talk on NBC Sports\r\nThe Buccanee...
# 99  Hundreds of thousands of Bitcoin transactions ...
#
#                                                tokens
# 0   [even, if, you, arent, paying, attention, to, ...
# 1   [when, denis, rusinovich, set, up, cryptocurre...
# 2   [el, salvador, introduced, bitcoin, a, a, lega...
# 3   [were, officially, building, an, open, bitcoin...
# 4   [israeli, national, tal, prihar, pled, guilty,...
# ..                                                ...
# 95  [quantum, computer, would, need, to, become, a...
# 96  [u, stock, future, slipped, monday, after, the...
# 97  [anna, moneymakergettyon, sept, according, to,...
# 98  [profootball, talk, on, nbc, sportsthe, buccan...
# 99  [hundred, of, thousand, of, bitcoin, transacti...
#
# [100 rows x 6 columns]

# %%
# Create a new tokens column for Ethereum
ethereum_df['tokens'] = ethereum_df['Text'].apply(tokenizer)
ethereum_df
# Out:
#     Compound  Positive  Negative  Neutral  \
# 0     0.0000     0.000     0.000    1.000
# 1     0.0000     0.000     0.000    1.000
# 2     0.1779     0.052     0.000    0.948
# 3     0.0772     0.038     0.000    0.962
# 4    -0.2023     0.039     0.062    0.899
# 5     0.0000     0.000     0.000    1.000
# 6    -0.1027     0.056     0.067    0.877
# 7     0.0000     0.000     0.000    1.000
# 8     0.4019     0.085     0.000    0.915
# 9    -0.0557     0.041     0.047    0.911
# 10    0.5574     0.129     0.000    0.871
# 11    0.0000     0.000     0.000    1.000
# 12    0.4215     0.106     0.000    0.894
# 13    0.4215     0.106     0.000    0.894
# 14    0.1027     0.131     0.092    0.778
# 15   -0.6808     0.051     0.174    0.775
# 16    0.1027     0.046     0.000    0.954
# 17    0.6808     0.185     0.000    0.815
# 18    0.0000     0.000     0.000    1.000
# 19    0.0000     0.000     0.000    1.000
#
#                                                  Text  \
# 0   In a new blog post the company said that 4,836...
# 1   Hackers who made off with roughly $15 million ...
# 2   On some level, the new mayor is simply employi...
# 3   Back in September\r\n, Robinhood announced pla...
# 4   If people who buy cryptocurrencies intended on...
# 5   This enables an L1 platform to bootstrap its n...
# 6   Trading platform Crypto.com lost about $34 mil...
# 7   The means-and-ends moralists, or non-doers, al...
# 8   Ethereum is a digital platform that runs on bl...
# 9   Crypto bros never tire of sharing their utopia...
# 10  The crypto market's whiplash volatility can ma...
# 11  Feb 7 (Reuters) - Polygon, a decentralized sca...
# 12  TO BELIEVERS, OPEN, public blockchains provide...
# 13  TO BELIEVERS, OPEN, public blockchains provide...
# 14  Online thieves made off with "wrapped ethereum...
# 15  Online thieves made off with 120,000 wEth, or ...
# 16  In an interview with Bloomberg TV, Crypto.com'...
# 17  British entrepreneur and financier Richard ODe...
# 18  Feb 4 (Reuters) - Bitcoin surged 8.82% to $40,...
# 19  A version of this article was published in TIM...
#
#                                                tokens
# 0   [in, a, new, blog, post, the, company, said, t...
# 1   [hacker, who, made, off, with, roughly, millio...
# 2   [on, some, level, the, new, mayor, is, simply,...
# 3   [back, in, september, robinhood, announced, pl...
# 4   [if, people, who, buy, cryptocurrencies, inten...
# 5   [this, enables, an, l, platform, to, bootstrap...
# 6   [trading, platform, cryptocom, lost, about, mi...
# 7   [the, meansandends, moralist, or, nondoers, al...
# 8   [ethereum, is, a, digital, platform, that, run...
# 9   [crypto, bros, never, tire, of, sharing, their...
# 10  [the, crypto, market, whiplash, volatilitycan,...
# 11  [feb, reuters, polygon, a, decentralized, scal...
# 12  [to, believer, open, public, blockchains, prov...
# 13  [to, believer, open, public, blockchains, prov...
# 14  [online, thief, made, off, with, wrapped, ethe...
# 15  [online, thief, made, off, with, weth, or, wra...
# 16  [in, an, interview, with, bloomberg, tv, crypt...
# 17  [british, entrepreneur, and, financier, richar...
# 18  [feb, reuters, bitcoin, surged, to, at, gmt, o...
# 19  [a, version, of, this, article, wa, published,...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
def get_token(df):
    tokens = []
    for i in df['tokens']:
        tokens.extend(i)
    return tokens

btc_tokens = get_token(bitcoin_df)
eth_tokens = get_token(ethereum_df)

# %%
# Generate the Bitcoin N-grams where N=2
def bigram_counter(tokens, N):
    words_count = dict(Counter(ngrams(tokens, n=2)))
    return words_count

# %%
# Generate the Ethereum N-grams where N=2
bigram_eth = bigram_counter(eth_tokens, 2)
bigram_eth
# Out:
# {('in', 'a'): 2,
#  ('a', 'new'): 3,
#  ('new', 'blog'): 2,
#  ('blog', 'post'): 3,
#  ('post', 'the'): 1,
#  ('the', 'company'): 4,
#  ('company', 'said'): 2,
#  ('said', 'that'): 1,
#  ('that', 'eth'): 1,
#  ('eth', 'and'): 1,
#  ('and', 'bitcoin'): 1,
#  ('bitcoin', 'were'): 1,
#  ('were', 'takenillustration'): 1,
#  ('takenillustration', 'by'): 1,
#  ('by', 'alex'): 1,
#  ('alex', 'castro'): 1,
#  ('castro', 'the'): 1,
#  ('the', 'vergein'): 1,
#  ('vergein', 'a'): 1,
#  ('a', 'blog'): 1,
#  ('post', 'published'): 1,
#  ('published', 'in'): 2,
#  ('in', 'the'): 1,
#  ('the', 'early'): 1,
#  ('early', 'hour'): 1,
#  ('hour', 'of'): 1,
#  ('of', 'thursday'): 1,
#  ('thursday', 'morning'): 1,
#  ('morning', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'char'): 1,
#  ('char', 'hacker'): 1,
#  ('hacker', 'who'): 1,
#  ('who', 'made'): 1,
#  ('made', 'off'): 3,
#  ('off', 'with'): 3,
#  ('with', 'roughly'): 1,
#  ('roughly', 'million'): 1,
#  ('million', 'in'): 4,
#  ('in', 'ethereum'): 1,
#  ('ethereum', 'from'): 1,
#  ('from', 'cryptocom'): 1,
#  ('cryptocom', 'are'): 1,
#  ('are', 'attempting'): 1,
#  ('attempting', 'to'): 1,
#  ('to', 'launder'): 1,
#  ('launder', 'the'): 1,
#  ('the', 'fund'): 1,
#  ('fund', 'through'): 1,
#  ('through', 'a'): 2,
#  ('a', 'socalled'): 1,
#  ('socalled', 'ethereum'): 1,
#  ('ethereum', 'mixer'): 1,
#  ('mixer', 'known'): 1,
#  ('known', 'a'): 1,
#  ('a', 'tornado'): 1,
#  ('tornado', 'cash'): 1,
#  ('cash', 'according'): 1,
#  ('according', 'to'): 2,
#  ('to', 'a'): 3,
#  ('new', 'report'): 1,
#  ('report', 'from'): 1,
#  ('from', 'char'): 1,
#  ('char', 'on'): 1,
#  ('on', 'some'): 1,
#  ('some', 'level'): 1,
#  ('level', 'the'): 1,
#  ('the', 'new'): 1,
#  ('new', 'mayor'): 1,
#  ('mayor', 'is'): 1,
#  ('is', 'simply'): 1,
#  ('simply', 'employing'): 1,
#  ('employing', 'an'): 1,
#  ('an', 'ageold'): 1,
#  ('ageold', 'political'): 1,
#  ('political', 'strategy'): 1,
#  ('strategy', 'making'): 1,
#  ('making', 'overture'): 1,
#  ('overture', 'to'): 1,
#  ('to', 'the'): 2,
#  ('the', 'business'): 1,
#  ('business', 'community'): 1,
#  ('community', 'fintech'): 1,
#  ('fintech', 'is'): 1,
#  ('is', 'a'): 2,
#  ('a', 'growing'): 1,
#  ('growing', 'field'): 1,
#  ('field', 'in'): 1,
#  ('in', 'new'): 1,
#  ('new', 'york'): 1,
#  ('york', 'city'): 1,
#  ('city', 'and'): 1,
#  ('and', 'blockchainbased'): 1,
#  ('blockchainbased', 'company'): 1,
#  ('company', 'char'): 1,
#  ('char', 'back'): 1,
#  ('back', 'in'): 1,
#  ('in', 'september'): 1,
#  ('september', 'robinhood'): 1,
#  ('robinhood', 'announced'): 1,
#  ('announced', 'plan'): 1,
#  ('plan', 'to'): 1,
#  ('to', 'test'): 1,
#  ('test', 'a'): 1,
#  ('a', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'wallet'): 1,
#  ('wallet', 'within'): 1,
#  ('within', 'it'): 1,
#  ('it', 'app'): 1,
#  ('app', 'at'): 1,
#  ('at', 'the'): 1,
#  ('the', 'time'): 1,
#  ('time', 'the'): 1,
#  ('said', 'it'): 1,
#  ('it', 'would'): 1,
#  ('would', 'open'): 1,
#  ('open', 'the'): 1,
#  ('the', 'beta'): 1,
#  ('beta', 'to'): 1,
#  ('a', 'small'): 1,
#  ('small', 'number'): 1,
#  ('number', 'of'): 1,
#  ('of', 'people'): 1,
#  ('people', 'before'): 1,
#  ('before', 'expanding'): 1,
#  ('expanding', 'availa'): 1,
#  ('availa', 'char'): 1,
#  ('char', 'if'): 1,
#  ('if', 'people'): 1,
#  ('people', 'who'): 1,
#  ('who', 'buy'): 1,
#  ('buy', 'cryptocurrencies'): 1,
#  ('cryptocurrencies', 'intended'): 1,
#  ('intended', 'only'): 1,
#  ('only', 'to'): 1,
#  ('to', 'hold'): 1,
#  ('hold', 'on'): 1,
#  ('on', 'to'): 1,
#  ('to', 'them'): 1,
#  ('them', 'a'): 1,
#  ('a', 'speculative'): 1,
#  ('speculative', 'investment'): 1,
#  ('investment', 'thered'): 1,
#  ('thered', 'be'): 1,
#  ('be', 'no'): 1,
#  ('no', 'real'): 1,
#  ('real', 'need'): 1,
#  ('need', 'for'): 1,
#  ('for', 'crypto'): 1,
#  ('crypto', 'wallet'): 1,
#  ('wallet', 'exchange'): 1,
#  ('exchange', 'and'): 1,
#  ('and', 'online'): 1,
#  ('online', 'brokerage'): 1,
#  ('brokerage', 'that'): 1,
#  ('that', 'convert'): 1,
#  ('convert', 'dollar'): 1,
#  ('dollar', 'to'): 1,
#  ('to', 'sa'): 1,
#  ('sa', 'char'): 1,
#  ('char', 'this'): 1,
#  ('this', 'enables'): 1,
#  ('enables', 'an'): 1,
#  ('an', 'l'): 1,
#  ('l', 'platform'): 1,
#  ('platform', 'to'): 1,
#  ('to', 'bootstrap'): 1,
#  ('bootstrap', 'it'): 1,
#  ('it', 'national'): 1,
#  ('national', 'economy'): 1,
#  ('economy', 'over'): 1,
#  ('over', 'time'): 1,
#  ('time', 'through'): 1,
#  ('a', 'flywheel'): 1,
#  ('flywheel', 'between'): 1,
#  ('between', 'financial'): 1,
#  ('financial', 'speculation'): 1,
#  ('speculation', 'around'): 1,
#  ('around', 'it'): 1,
#  ('it', 'native'): 1,
#  ('native', 'token'): 1,
#  ('token', 'and'): 1,
#  ('and', 'actual'): 1,
#  ('actual', 'building'): 1,
#  ('building', 'of'): 1,
#  ('of', 'application'): 1,
#  ('application', 'and'): 1,
#  ('and', 'activity'): 1,
#  ('activity', 'in'): 1,
#  ('in', 'char'): 4,
#  ('char', 'trading'): 1,
#  ('trading', 'platform'): 1,
#  ('platform', 'cryptocom'): 1,
#  ('cryptocom', 'lost'): 1,
#  ('lost', 'about'): 1,
#  ('about', 'million'): 1,
#  ('million', 'worth'): 1,
#  ('worth', 'of'): 1,
#  ('of', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'in'): 1,
#  ('a', 'hack'): 1,
#  ('hack', 'on'): 1,
#  ('on', 'monday'): 2,
#  ('monday', 'according'): 1,
#  ('post', 'by'): 1,
#  ('by', 'the'): 2,
#  ('company', 'published'): 1,
#  ('published', 'overnight'): 1,
#  ('overnight', 'the'): 1,
#  ('company', 'had'): 1,
#  ('had', 'previously'): 1,
#  ('previously', 'declined'): 1,
#  ('declined', 'to'): 1,
#  ('to', 'char'): 1,
#  ('char', 'the'): 2,
#  ('the', 'meansandends'): 1,
#  ('meansandends', 'moralist'): 1,
#  ('moralist', 'or'): 1,
#  ('or', 'nondoers'): 1,
#  ('nondoers', 'always'): 1,
#  ('always', 'end'): 1,
#  ('end', 'up'): 1,
#  ('up', 'on'): 1,
#  ('on', 'their'): 1,
#  ('their', 'endswithout'): 1,
#  ('endswithout', 'any'): 1,
#  ('any', 'mean'): 1,
#  ('mean', 'saul'): 1,
#  ('saul', 'alinsky'): 1,
#  ('alinsky', 'ethereum'): 1,
#  ('ethereum', 'is'): 1,
#  ('a', 'digital'): 3,
#  ('digital', 'platform'): 1,
#  ('platform', 'that'): 1,
#  ('that', 'run'): 1,
#  ('run', 'on'): 1,
#  ('on', 'blockchain'): 1,
#  ('blockchain', 'technology'): 1,
#  ('technology', 'it'): 1,
#  ('it', 'most'): 1,
#  ('most', 'commonly'): 1,
#  ('commonly', 'known'): 1,
#  ('known', 'for'): 1,
#  ('for', 'it'): 1,
#  ('it', 'smart'): 1,
#  ('smart', 'contract'): 1,
#  ('contract', 'functionality'): 1,
#  ('functionality', 'and'): 1,
#  ('and', 'native'): 1,
#  ('native', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'ether'): 1,
#  ('ether', 'the'): 1,
#  ('the', 'broader'): 1,
#  ('broader', 'purpose'): 1,
#  ('purpose', 'of'): 1,
#  ('of', 'the'): 3,
#  ('the', 'ethereum'): 2,
#  ('ethereum', 'char'): 1,
#  ('char', 'crypto'): 1,
#  ('crypto', 'bros'): 1,
#  ('bros', 'never'): 1,
#  ('never', 'tire'): 1,
#  ('tire', 'of'): 1,
#  ('of', 'sharing'): 1,
#  ('sharing', 'their'): 1,
#  ('their', 'utopian'): 1,
#  ('utopian', 'vision'): 1,
#  ('vision', 'but'): 1,
#  ('but', 'their'): 1,
#  ('their', 'big'): 1,
#  ('big', 'brain'): 1,
#  ('brain', 'idea'): 1,
#  ('idea', 'arent'): 1,
#  ('arent', 'always'): 1,
#  ('always', 'embraced'): 1,
#  ('embraced', 'by'): 1,
#  ('the', 'prolesvitalik'): 1,
#  ('prolesvitalik', 'buterin'): 1,
#  ('buterin', 'the'): 1,
#  ('the', 'cofounder'): 1,
#  ('cofounder', 'and'): 1,
#  ('and', 'inventor'): 1,
#  ('inventor', 'of'): 1,
#  ('of', 'ethereum'): 1,
#  ('ethereum', 'ha'): 1,
#  ('ha', 'become'): 1,
#  ('become', 'the'): 1,
#  ('the', 'lates'): 1,
#  ('lates', 'char'): 1,
#  ('the', 'crypto'): 1,
#  ('crypto', 'market'): 1,
#  ('market', 'whiplash'): 1,
#  ('whiplash', 'volatilitycan'): 1,
#  ('volatilitycan', 'make'): 1,
#  ('make', 'investing'): 1,
#  ('investing', 'in'): 1,
#  ('in', 'certain'): 1,
#  ('certain', 'coin'): 1,
#  ('coin', 'feel'): 1,
#  ('feel', 'like'): 1,
#  ('like', 'a'): 1,
#  ('a', 'major'): 1,
#  ('major', 'gamble'): 1,
#  ('gamble', 'especially'): 1,
#  ('especially', 'to'): 1,
#  ('to', 'those'): 1,
#  ('those', 'le'): 1,
#  ('le', 'familiarwith'): 1,
#  ('familiarwith', 'the'): 1,
#  ('the', 'in'): 3,
#  ('in', 'and'): 1,
#  ('and', 'out'): 1,
#  ('out', 'of'): 1,
#  ('of', 'digital'): 1,
#  ('digital', 'wallet'): 1,
#  ('wallet', 'and'): 1,
#  ('and', 'blockchain'): 1,
#  ('blockchain', 'technol'): 1,
#  ('technol', 'char'): 1,
#  ('char', 'feb'): 2,
#  ('feb', 'reuters'): 2,
#  ('reuters', 'polygon'): 1,
#  ('polygon', 'a'): 1,
#  ('a', 'decentralized'): 1,
#  ('decentralized', 'scaling'): 1,
#  ('scaling', 'platform'): 1,
#  ('platform', 'for'): 1,
#  ('for', 'the'): 1,
#  ('ethereum', 'blockchain'): 1,
#  ('blockchain', 'announced'): 1,
#  ('announced', 'on'): 1,
#  ('monday', 'it'): 1,
#  ('it', 'ha'): 1,
#  ('ha', 'raised'): 1,
#  ('raised', 'million'): 1,
#  ('in', 'it'): 1,
#  ('it', 'latest'): 1,
#  ('latest', 'funding'): 1,
#  ('funding', 'round'): 1,
#  ('round', 'led'): 1,
#  ('led', 'by'): 1,
#  ('by', 'sequoia'): 1,
#  ('sequoia', 'capital'): 1,
#  ('capital', 'india'): 1,
#  ('india', 'and'): 1,
#  ('and', 'in'): 1,
#  ('char', 'to'): 2,
#  ('to', 'believer'): 2,
#  ('believer', 'open'): 2,
#  ('open', 'public'): 2,
#  ('public', 'blockchains'): 2,
#  ('blockchains', 'provide'): 2,
#  ('provide', 'a'): 2,
#  ('a', 'second'): 2,
#  ('second', 'chance'): 2,
#  ('chance', 'at'): 2,
#  ('at', 'building'): 2,
#  ('building', 'a'): 2,
#  ('digital', 'economy'): 2,
#  ('economy', 'the'): 2,
#  ('the', 'fact'): 2,
#  ('fact', 'that'): 2,
#  ('that', 'the'): 4,
#  ('the', 'application'): 2,
#  ('application', 'built'): 2,
#  ('built', 'on'): 2,
#  ('on', 'top'): 2,
#  ('top', 'of'): 2,
#  ('of', 'such'): 2,
#  ('such', 'blockchains'): 2,
#  ('blockchains', 'all'): 2,
#  ('all', 'work'): 2,
#  ('work', 'with'): 2,
#  ('with', 'each'): 2,
#  ('each', 'other'): 2,
#  ('other', 'and'): 2,
#  ('and', 'that'): 2,
#  ('char', 'online'): 2,
#  ('online', 'thief'): 2,
#  ('thief', 'made'): 2,
#  ('with', 'wrapped'): 1,
#  ('wrapped', 'ethereum'): 2,
#  ('ethereum', 'worth'): 2,
#  ('worth', 'nearly'): 2,
#  ('nearly', 'milliongetty'): 2,
#  ('milliongetty', 'imageshackers'): 2,
#  ('imageshackers', 'stole'): 1,
#  ('stole', 'more'): 1,
#  ('more', 'than'): 2,
#  ('than', 'million'): 2,
#  ('in', 'cryptocurrency'): 2,
#  ('cryptocurrency', 'from'): 2,
#  ('from', 'wormhole'): 2,
#  ('wormhole', 'the'): 2,
#  ('the', 'developer'): 2,
#  ('developer', 'behind'): 1,
#  ('behind', 'the'): 1,
#  ('the', 'popular'): 1,
#  ('popular', 'block'): 1,
#  ('block', 'char'): 1,
#  ('with', 'weth'): 1,
#  ('weth', 'or'): 1,
#  ('or', 'wrapped'): 1,
#  ('imageshackers', 'have'): 1,
#  ('have', 'stolen'): 1,
#  ('stolen', 'more'): 1,
#  ('developer', 'be'): 1,
#  ('be', 'char'): 1,
#  ('char', 'in'): 1,
#  ('in', 'an'): 1,
#  ('an', 'interview'): 1,
#  ('interview', 'with'): 1,
#  ('with', 'bloomberg'): 1,
#  ('bloomberg', 'tv'): 1,
#  ('tv', 'cryptocoms'): 1,
#  ('cryptocoms', 'chief'): 1,
#  ('chief', 'executive'): 1,
#  ('executive', 'kris'): 1,
#  ('kris', 'marszalek'): 1,
#  ('marszalek', 'ha'): 1,
#  ('ha', 'admitted'): 1,
#  ('admitted', 'that'): 1,
#  ('that', 'customer'): 1,
#  ('customer', 'account'): 1,
#  ('account', 'were'): 1,
#  ('were', 'compromised'): 1,
#  ('compromised', 'by'): 1,
#  ('by', 'hacker'): 1,
#  ('hacker', 'he'): 1,
#  ('he', 'said'): 1,
#  ('said', 'his'): 1,
#  ('his', 'team'): 1,
#  ('team', 'detected'): 1,
#  ('detected', 'unauthorized'): 1,
#  ('unauthorized', 'transaction'): 1,
#  ('transaction', 'char'): 1,
#  ('char', 'british'): 1,
#  ('british', 'entrepreneur'): 1,
#  ('entrepreneur', 'and'): 1,
#  ('and', 'financier'): 1,
#  ('financier', 'richard'): 1,
#  ('richard', 'odell'): 1,
#  ('odell', 'poulden'): 1,
#  ('poulden', 'hope'): 1,
#  ('hope', 'that'): 1,
#  ('that', 'his'): 1,
#  ('his', 'new'): 1,
#  ('new', 'venture'): 1,
#  ('venture', 'will'): 1,
#  ('will', 'relieve'): 1,
#  ('relieve', 'the'): 1,
#  ('the', 'plight'): 1,
#  ('plight', 'of'): 1,
#  ('of', 'an'): 1,
#  ('an', 'underserved'): 1,
#  ('underserved', 'cohort'): 1,
#  ('cohort', 'bitcoin'): 1,
#  ('bitcoin', 'billionaire'): 1,
#  ('billionaire', 'who'): 1,
#  ('who', 'want'): 1,
#  ('want', 'to'): 1,
#  ('to', 'buy'): 1,
#  ('buy', 'a'): 1,
#  ('a', 'housein'): 1,
#  ('housein', 'october'): 1,
#  ('october', 'poulde'): 1,
#  ('poulde', 'char'): 1,
#  ('reuters', 'bitcoin'): 1,
#  ('bitcoin', 'surged'): 1,
#  ('surged', 'to'): 1,
#  ('to', 'at'): 1,
#  ('at', 'gmt'): 1,
#  ('gmt', 'on'): 1,
#  ('on', 'friday'): 1,
#  ('friday', 'adding'): 1,
#  ('adding', 'to'): 1,
#  ('to', 'it'): 1,
#  ('it', 'previous'): 1,
#  ('previous', 'closebitcoin'): 1,
#  ('closebitcoin', 'the'): 1,
#  ('the', 'world'): 1,
#  ('world', 'biggest'): 1,
#  ('biggest', 'and'): 1,
#  ('and', 'bestknown'): 1,
#  ('bestknown', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'is'): 1,
#  ('is', 'up'): 1,
#  ('up', 'from'): 1,
#  ('from', 'the'): 1,
#  ('the', 'ye'): 1,
#  ('ye', 'char'): 1,
#  ('char', 'a'): 1,
#  ('a', 'version'): 1,
#  ('version', 'of'): 1,
#  ('of', 'this'): 1,
#  ('this', 'article'): 1,
#  ('article', 'wa'): 1,
#  ('wa', 'published'): 1,
#  ('in', 'time'): 1,
#  ('time', 'newsletter'): 1,
#  ('newsletter', 'into'): 1,
#  ('into', 'the'): 1,
#  ('the', 'metaverse'): 1,
#  ('metaverse', 'subscribe'): 1,
#  ('subscribe', 'for'): 1,
#  ('for', 'a'): 1,
#  ('a', 'weekly'): 1,
#  ('weekly', 'guide'): 1,
#  ('guide', 'to'): 1,
#  ('the', 'future'): 1,
#  ('future', 'of'): 1,
#  ('the', 'internetyou'): 1,
#  ('internetyou', 'can'): 1,
#  ('can', 'find'): 1,
#  ('find', 'past'): 1,
#  ('past', 'issue'): 1,
#  ('issue', 'of'): 1,
#  ('the', 'newsletter'): 1,
#  ('newsletter', 'herewhen'): 1,
#  ('herewhen', 'vita'): 1,
#  ('vita', 'char'): 1}

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
token_count(btc_tokens, 10)
# Out:
# [('the', 142),
#  ('a', 117),
#  ('char', 99),
#  ('to', 94),
#  ('of', 75),
#  ('bitcoin', 65),
#  ('and', 59),
#  ('in', 59),
#  ('it', 49),
#  ('on', 47)]

# %%
# Use token_count to get the top 10 words for Ethereum
token_count(eth_tokens, 10)
# Out:
# [('the', 36),
#  ('a', 22),
#  ('char', 19),
#  ('to', 18),
#  ('in', 17),
#  ('and', 14),
#  ('of', 14),
#  ('that', 9),
#  ('on', 9),
#  ('it', 9)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
wc = WordCloud().generate(' '.join(btc_tokens))
plt.title("Bitcoin WordCloud", fontsize = 60, fontweight = 'bold')
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
wc = WordCloud().generate(' '.join(eth_tokens))
plt.title("Ethereum WordCloud", fontsize = 60, fontweight = 'bold')
plt.imshow(wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
btc_text = ' '.join(bitcoin_df['Text'])
btc_text
# Out:
# 'Even if you arent paying attention to Bitcoin and other cryptocurrencies, you might have noticed that their value plummeted last week, with the total value of the market tumbling from a high of $3 tr… [+4782 chars] When Denis Rusinovich set up cryptocurrency mining company Maveric Group in Kazakhstan in 2017, he thought he had hit the jackpot. Next door to China and Russia, the country had everything a Bitcoin … [+4140 chars] El Salvador introduced Bitcoin as a legal tender alongside the US dollar in 2021. | Illustration by Alex Castro / The Verge\r\n\n \n\n The International Monetary Fund’s executive board has recommended El … [+2691 chars] Were officially building an open Bitcoin mining system\r\nPhoto by Joe Raedle/Getty Images\r\nBlock, the payment company formerly known as Square, is working on building an open Bitcoin mining system, it… [+2078 chars] Israeli national Tal Prihar pled guilty to routing money from kickbacks through Bitcoin and shell companies \r\nIllustration by Alex Castro / The Verge\r\nIn the culmination of a two-year legal process, … [+1448 chars] In a new blog post the company said that 4,836 ETH and 443 bitcoin were taken\r\nIllustration by Alex Castro / The Verge\r\nIn a blog post published in the early hours of Thursday morning, cryptocurrency… [+2004 chars] Netflix\r\n is making a docuseries about one of the worst rappers of all time\r\n. Coincidentally, Heather "Razzlekhan" Morgan and her husband, Ilya Lichtenstein, were charged this week with conspiring t… [+1432 chars] Bitcoin, the largest digital asset, extended its decline Saturday, and has now shed more than 50% from its record high in November.Bitcoin’s decline since hitting the record has wiped out more than $… [+567 chars] Block founder Jack Dorsey has announced on Twitter that the company is officially building an open bitcoin mining system. Dorsey first announced in October last year that the digital payments provide… [+1584 chars] Tesla Inc (TSLA.O) will accept the meme-based cryptocurrency dogecoin as payment for its products such as the "Giga Texas" belt buckle and mini\xa0 electric vehicle models, CEO Elon Musk said on Friday … [+1482 chars] On some level, the new mayor is simply employing an age-old political strategy: making overtures to the business community. Fintech is a growing field in New York City, and blockchain-based companies… [+1562 chars] British entrepreneur and financier Richard ODell Poulden hopes that his new venture will relieve the plight of an underserved cohort: Bitcoin billionaires who want to buy a house.\r\nIn October, Poulde… [+3364 chars] Russia\'s central bank on Thursday proposed banning the use and mining of cryptocurrencies\xa0on Russian territory, citing threats to financial stability, citizens\' wellbeing and its monetary policy sove… [+2149 chars] Over the last five years, about 25,000 of those Bitcoin were transferred out of Mr. Lichtensteins wallet using a complicated series of transactions meant to obscure that the currency had been stolen … [+2506 chars] Image caption, Bitcoin is accepted everywhere for goods and services in El Salvador, alongside the US dollar\r\nThe International Monetary Fund (IMF) has urged El Salvador to reverse its decision to ma… [+1846 chars] By Reuters Staff\r\nJan 26 (Reuters) - The U.S. Securities and Exchange Commission on Thursday rejected a proposal to offer spot bitcoin exchange-traded funds (ETF) from Fidelitys Wise Origin Bitcoin T… [+202 chars] Jack Dorsey onstage at a bitcoin convention in June.Joe Raedle/Getty Images\r\nBlock is going ahead with building a bitcoin mining system that will be open to individuals and businesses worldwide, its … [+2459 chars] The news of one of the biggest money laundering schemes in history captivated the world on Tuesday, not so much because of the crimewhich involved $4.5 billion in bitcoin and is, yeah, a big dealbut … [+1948 chars] Back in September\r\n, Robinhood announced plans to test a cryptocurrency wallet within its ap ...

# %%
# Run the NER processor on all of the text
doc = nlp(btc_text)


# Add a title to the document
doc.user_data["title"] = "BITCOIN NER"

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">BITCOIN NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Even if you arent paying attention to Bitcoin and other cryptocurrencies, you might have noticed that their value plummeted
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , with the total value of the market tumbling from a high of $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  tr… [+4782 chars] When
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Denis Rusinovich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  set up cryptocurrency mining company
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maveric Group
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kazakhstan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , he thought he had hit the jackpot. Next door to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , the country had everything a Bitcoin … [+4140 chars]
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  introduced Bitcoin as a legal tender alongside the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  dollar in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . | Illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alex Castro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  / The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Verge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br></br> </br></br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The International Monetary Fund’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  executive board has recommended
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  … [+2691 chars] Were officially building an open
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Photo by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joe Raedle/Getty Images
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Block, the payment company formerly known as
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Square
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# , is working on building an open
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  mining system, it… [+2078 chars]
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Israeli
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  national
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tal Prihar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Illustration
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alex Castro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  / The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Verge
#     <sp

# %%
# List all Entities
for ent in doc.ents:
    print('{} {}'.format(ent.text, ent.label_))
# Out:
# last week DATE
# 3 MONEY
# Denis Rusinovich PERSON
# Maveric Group ORG
# Kazakhstan GPE
# 2017 DATE
# China GPE
# Russia GPE
# El Salvador GPE
# US GPE
# 2021 DATE
# Alex Castro PERSON
# Verge ORG
# The International Monetary Fund’s ORG
# El ORG
# Bitcoin PERSON
# Joe Raedle/Getty Images PERSON
# Square FAC
# Bitcoin PERSON
# Israeli NORP
# Tal Prihar PERSON
# Illustration ORG
# Alex Castro PERSON
# Verge ORG
# two-year DATE
# 4,836 CARDINAL
# ETH ORG
# 443 CARDINAL
# Alex Castro PERSON
# Verge ORG
# the early hours TIME
# Thursday DATE
# morning TIME
# Netflix ORG
# about one CARDINAL
# Ilya Lichtenstein PERSON
# this week DATE
# Saturday DATE
# more than 50% PERCENT
# November DATE
# more than $ MONEY
# Jack Dorsey PERSON
# Twitter PRODUCT
# first ORDINAL
# October last year DATE
# the "Giga Texas ORG
# Elon Musk PERSON
# Friday DATE
# Fintech ORG
# New York City GPE
# British NORP
# Richard ODell PERSON
# house ORG
# October DATE
# Poulde GPE
# Russia GPE
# Thursday DATE
# Russian NORP
# the last five years DATE
# about 25,000 CARDINAL
# Lichtensteins PERSON
# Bitcoin PERSON
# El Salvador GPE
# US GPE
# The International Monetary Fund ORG
# El Salvador GPE
# Reuters ORG
# Jan 26 DATE
# Reuters ORG
# The U.S. Securities and Exchange Commission ORG
# Thursday DATE
# ETF ORG
# Fidelitys Wise Origin Bitcoin ORG
# +202 GPE
# Jack Dorsey PERSON
# June DATE
# Joe Raedle/Getty Images PERSON
# one CARDINAL
# Tuesday DATE
# $4.5 billion MONEY
# September DATE
# Robinhood ORG
# one CARDINAL
# 2020 DATE
# Crypto.com ORG
# about $34 million MONEY
# Monday DATE
# One CARDINAL
# the European Unions ORG
# European Securities ORG
# Feb 1 DATE
# Reuters ORG
# thousands CARDINAL
# 202 CARDINAL
# Feb 4 DATE
# Reuters ORG
# 8.82% PERCENT
# 40,611.4 MONEY
# 2202 DATE
# Friday DATE
# 3,291.29 MONEY
# Bitcoin PERSON
# 23.2% PERCENT
# Bitcoin PERSON
# January 8, 2021 DATE
# REUTERS ORG
# Dado Ruvic/File PhotoJan PERSON
# 21 CARDINAL
# Reuters ORG
# 9.28% PERCENT
# 36 MONEY
# January 24, 2022 - DATE
# Ponzi ORG
# Elon Musk PERSON
# mid-May DATE
# Spain GPE
# more than 100,000 CARDINAL
# Trump White House ORG
# Anthony Scaramucci PERSON
# AP Photo/Pablo Martinez Monsivais ORG
# File ORG
# SkyBridge Capital ORG
# Anthony Scaramucci PERSON
# Bloombergs Lorcan Roche Kelly ORG
# first ORDINAL
# the 21st cen DATE
# almost half CARDINAL
# November DATE
# Bitcoin PERSON
# LONDON GPE
# Jan 24 DATE
# Reuters ORG
# over 7% PERCENT
# Monday DATE
# six months DATE
# Russian NORP
# Ukraine GPE
# Feb 8 DATE
# Reuters ORG
# 2022 DATE
# NEW YORK GPE
# Feb 11 DATE
# Reuters ORG
# Federal Reserve ORG
# the U.S. Securities and Exchange Commission ORG
# SEC ORG
# Washington GPE
# D.C. GPE
# U.S. GPE
# May 12, 2021 DATE
# May 12, 2021 DATE
# REUTERS ORG
# Andrew Kelly PERSON
# Intercon ORG
# LONDON GPE
# NEW YORK GPE
# Jan 24 DATE
# Reuters ORG
# six months DATE
# Monday DATE
# Russian NORP
# Ukraine GPE
# Feb 11 DATE
# Reuters ORG
# Intel Corp ORG
# Friday DATE
# Fed ORG
# LONDON GPE
# Jan 14 DATE
# Reuters ORG
# Kazakhstan GPE
# Jan 25 DATE
# Reuters ORG
# 13 CARDINAL
# this year DATE
# U.S. Justice Department ORG
# Tuesday DATE
# $3.6 billion MONEY
# 2016 DATE
# NEW YORK GPE
# Feb 9 DATE
# Tuesday DATE
# Ilya Dutch Lich ORG
# El Salvador GPE
# Jan 25 DATE
# Reuters ORG
# El Salvador GPE
# Jan 17 DATE
# Reuters ORG
# 2022 DATE
# December DATE
# +3835 ORG
# A year ago DATE
# February 8 DATE
# $1.5 billion MONEY
# three CARDINAL
# one CARDINAL
# Tesla ORG
# $20 million MONEY
# $220 million MONEY
# CoinDesk ORG
# Intelligence ORG
# 2021 DATE
# Michael Saylor PERSON
# MicroStrategyJoe Raedle/Getty Images ORG
# MicroStrategy ORG
# two-day DATE
# 30% PERCENT
# Monday DATE
# SEC ORG
# MicroStrategy ORG
# $146.6 million MONEY
# the fourth quarter of 2021 DATE
# six-fold CARDINAL
# the same period last year DATE
# Treasury ORG
# Alejandro Zelaya PERSON
# Zelaya PERSON
# Bitcoin PERSON
# +607 ORG
# the past 12 years DATE
# Anthony Welch PERSON
# Theresa PERSON
# Robinson Crusoe ORG
# South Pacific LOC
# Welch ORG
# British NORP
# Reuters ORG
# NEW YORK GPE
# Jan 27 DATE
# Reuters ORG
# the International Monetary Fund ORG
# El Salvador GPE
# $800 million MONEY
# El Salvador's GPE
# $10 million MONEY
# this quarter DATE
# CoinDesk ORG
# 2009 DATE
# first ORDINAL
# Jan 13 DATE
# Reuters ORG
# BTCS Inc ORG
# Thursday DATE
# four-day DATE
# NEW YORK GPE
# Jan 14 DATE
# Reuters ORG
# last year DATE
# Thomson Reuters Foundation ORG
# The International Monetary Fund ORG
# El Salvador GPE
# NEW YORK GPE
# Jan 12 DATE
# Reuters ORG
# Brazilian NORP
# Latin America's LOC
# Mercado Bitcoin PERSON
# Wednesday DATE
# NEW YORK GPE
# LONDON GPE
# Jan 24 DATE
# Reuters ORG
# the day on DATE
# Monday DATE
# six months DATE
# Russian NORP
# Recasts NORP
# NEW YORK GPE
# LONDON GPE
# Jan 24 DATE
# Reuters ORG
# the day on DATE
# Monday DATE
# HONG KONG GPE
# Jan 24 DATE
# Reuters ORG
# Monday DATE
# the U.S. Federal Reserve's ORG
# January DATE
# later this week DATE
# six-month DATE
# Feb 3 DATE
# Reuters ORG
# last year's DATE
# Thursday DATE
# LONDON GPE
# Feb 8 DATE
# Reuters ORG
# Ukrainian GPE
# 20 CARDINAL
# Mike Novogratz PERSON
# $3.6 billion MONEY
# 2016 DATE
# Bitfinex ORG
# today DATE
# Jack Dorsey PERSON
# Bitcoin Legal Defense Fund ORG
# Intelligence ORG
# Crypto PERSON
# Dorsey ORG
# Tuesday DATE
# Meta ORG
# Diem ORG
# Libra NORP
# this week DATE
# Dorsey PERSON
# Meta PERSON
# ZDNet ORG
# Steven Vaughan-Nichols PERSON
# Linus Torvalds ORG
# Satoshi Nakamoto PERSON
# first ORDINAL
# roughly $15 million MONEY
# Crypto.com ORG
# Tornado Cash PERSON
# Jack Dorsey PERSON
# the U.S. House of Representatives Energy and Commerce Committee ORG
# Social Media's Role WORK_OF_ART
# ATM ORG
# Los Angeles GPE
# The Justice Department ORG
# New York GPE
# billions of dollars MONEY
# New York City GPE
# Eric Adams PERSON
# Bronx GPE
# New York City GPE
# New York GPE
# U.S. GPE
# January 3, 2022 DATE
# REUTERS ORG
# Carlo Allegri/File PERSON
# Elon Musk PERSON
# McDonald's ORG
# Tuesday DATE
# morning TIME
# Musk PERSON
# Cathie Wood's PERSON
# Ark Invest PERSON
# this week DATE
# second ORDINAL
# Ark Invest PERSON
# MOSCOW GPE
# Jan 20 DATE
# Reuters ORG
# Russia GPE
# Thursday DATE
# Russian NORP
# 2024 DATE
# Thailand GPE
# WASHINGTON GPE
# Feb 8 DATE
# Reuters ORG
# UBS ORG
# winter DATE
# Marvin Recinos/Getty Images PERSON
# winter DATE
# Bloomberg TV ORG
# Crypto.com ORG
# Kris Marszalek PERSON
# 400 CARDINAL
# Friday DATE
# morning TIME
# Dogecoin ORG
# more than 15% PERCENT
# Tesla ORG
# CNBC ORG
# US GPE
# 3.6bn MONEY
# 2016 CARDINAL
# El Salvadors ORG
# Nayib Bukeles PERSON
# six months DATE
# Monday DATE
# Russian NORP
# Ukraine GPE
# WASHINGTON GPE
# Feb 8 DATE
# Reuters ORG
# FBI ORG
# Tuesday DATE
# morning TIME
# 2016 DATE
# Bitfinex ORG
# NEW YORK GPE
# Jan 21 DATE
# Reuters ORG
# U.S. GPE
# the latest week DATE
# mid-September 2021 DATE
# Reuters ORG
# U.S GPE
# Knox PERSON
# Quantum ORG
# around one million CARDINAL
# today DATE
# US GPE
# Monday DATE
# the previous week DATE
# Thursday DATE
# above $42,000 MONEY
# Anna Moneymaker/GettyOn PERSON
# Sept. 4, 2017 DATE
# Joel Greenberg PERSON
# Matt Gaetz PERSON
# NBC Sports ORG
# Buccaneers PERSON
# Tom Brady PERSON
# June 1 DATE
# Brady PERSON
# Hundreds of thousands CARDINAL
# every day DATE
# Bitcoin PERSON

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
eth_text = ' '.join(ethereum_df['Text'])
eth_text
# Out:
# 'In a new blog post the company said that 4,836 ETH and 443 bitcoin were taken\r\nIllustration by Alex Castro / The Verge\r\nIn a blog post published in the early hours of Thursday morning, cryptocurrency… [+2004 chars] Hackers who made off with roughly $15 million in ethereum from Crypto.com are attempting to launder the funds through a so-called ethereum mixer, known as Tornado Cash, according to a new report from… [+3891 chars] On some level, the new mayor is simply employing an age-old political strategy: making overtures to the business community. Fintech is a growing field in New York City, and blockchain-based companies… [+1562 chars] Back in September\r\n, Robinhood announced plans to test a cryptocurrency wallet within its app. At the time, the company said it would open the beta to a small number of people before expanding availa… [+1069 chars] If people who buy cryptocurrencies intended only to hold on to them as speculative investments, there\'d be no real need for crypto wallets. Exchanges and online brokerages that convert dollars to, sa… [+3031 chars] This enables an L1 platform to bootstrap its national economy over time through a flywheel between financial speculation around its native token and actual building of applications and activities in … [+4057 chars] Trading platform Crypto.com lost about $34 million worth of cryptocurrency in a hack on Monday, according to a new blog post by the company published overnight. The company had previously declined to… [+2933 chars] The means-and-ends moralists, or non-doers, always end up on their ends\r\nwithout any means.\r\n-- Saul Alinsky Ethereum is a digital platform that runs on blockchain technology. It\'s most commonly known for its smart contract functionality and native cryptocurrency, ether. The broader purpose of the Ethereum … [+10591 chars] Crypto bros never tire of sharing their utopian visions, but their big brain ideas arent always embraced by the proles.\r\nVitalik Buterin, the co-founder and inventor of Ethereum, has become the lates… [+1727 chars] The crypto market\'s whiplash volatility\xa0can make investing in certain coins feel like a major gamble, especially to those less familiar\xa0with the ins and outs of digital wallets and blockchain technol… [+1986 chars] Feb 7 (Reuters) - Polygon, a decentralized scaling platform for the ethereum blockchain, announced on Monday it has raised $450 million in its latest funding round led by Sequoia Capital India and in… [+1641 chars] TO BELIEVERS, OPEN, public blockchains provide a second chance at building a digital economy. The fact that the applications built on top of such blockchains all work with each other, and that the in… [+6735 chars] TO BELIEVERS, OPEN, public blockchains provide a second chance at building a digital economy. The fact that the applications built on top of such blockchains all work with each other, and that the in… [+6577 chars] Online thieves made off with "wrapped ethereum" worth nearly $324 million.\r\nGetty Images\r\nHackers stole more than $324 million in cryptocurrency from Wormhole, the developers behind the popular block… [+1664 chars] Online thieves made off with 120,000 wEth, or wrapped Ethereum, worth nearly $324 million.\r\nGetty Images\r\nHackers have stolen more than $324 million in cryptocurrency from Wormhole, the developers be… [+1553 chars] In an interview with Bloomberg TV, Crypto.com\'s Chief Executive Kris Marszalek has admitted that 400 customer accounts were compromised by hackers. He said his team detected unauthorized transactions… [+2811 chars] British entrepreneur and financier Richard ODell Poulden hopes that his new venture will relieve the plight of an underserved cohort: Bitcoin billionaires who want to buy a house.\r\nIn October, Poulde… [+3364 chars] Feb 4 (Reuters) - Bitcoin surged 8.82% to $40,611.4 at 2202 GMT on Friday, adding $3,291.29 to its previous close.\r\nBitcoin, the world\'s biggest and best-known cryptocurrency, is up 23.2% from the ye ...

# %%
# Run the NER processor on all of the text
doc = nlp(eth_text)

# Add a title to the document
doc.user_data["title"] = "ETHEREUM NER"

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">ETHEREUM NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">In a new blog post the company said that
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4,836
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ETH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     443
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>Illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alex Castro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  / The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Verge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>In a blog post published in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the early hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , cryptocurrency… [+2004 chars] Hackers who made off with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     roughly $15 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in ethereum from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Crypto.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  are attempting to launder the funds through a so-called ethereum mixer, known as
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tornado Cash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , according to a new report from… [+3891 chars] On some level, the new mayor is simply employing an age-old political strategy: making overtures to the business community.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fintech
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is a growing field in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and blockchain-based companies… [+1562 chars] Back in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     September
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Robinhood
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  announced plans to test a cryptocurrency wallet within its app. At the time, the company said it would open the beta to a small number of people before expanding availa… [+1069 chars] If people who buy cryptocurrencies intended only to hold on to them as speculative investments, there'd be no real need for crypto wallets. Exchanges and online brokerages that convert dollars to, sa… [+3031 chars] This enables an L1 platform to bootstrap its national economy over time through a flywheel between financial speculation around its native token and actual building of applications and activities in … [+4057 chars] Trading platform
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Crypto.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  lost
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about $34 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  worth of cryptocurrency in a hack on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>--
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Saul Alinsky Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is a digital platform that runs on blockchain technology. It's most commonly known for its smart contract functionality and native cryptocurrency, ether. The broader purpose of the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vitalik Buterin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the co-founder and inventor of
# <mark class="entit

# %%
# List all Entities
for ent in doc.ents:
    print('{} {}'.format(ent.text, ent.label_))
# Out:
# 4,836 CARDINAL
# ETH ORG
# 443 CARDINAL
# Alex Castro PERSON
# Verge ORG
# the early hours TIME
# Thursday DATE
# morning TIME
# roughly $15 million MONEY
# Crypto.com ORG
# Tornado Cash PERSON
# Fintech ORG
# New York City GPE
# September DATE
# Robinhood ORG
# Crypto.com ORG
# about $34 million MONEY
# Monday DATE
# Saul Alinsky Ethereum ORG
# Ethereum ORG
# Vitalik Buterin PERSON
# Ethereum ORG
# Feb 7 DATE
# Reuters ORG
# Monday DATE
# $450 million MONEY
# Sequoia Capital India ORG
# OPEN ORG
# second ORDINAL
# OPEN ORG
# second ORDINAL
# nearly $324 million MONEY
# Getty Images PERSON
# more than $324 million MONEY
# Wormhole PERSON
# 120,000 CARDINAL
# wEth ORG
# Ethereum ORG
# nearly $324 million MONEY
# Getty Images PERSON
# more than $324 million MONEY
# Wormhole PERSON
# Bloomberg TV ORG
# Crypto.com ORG
# Kris Marszalek PERSON
# 400 CARDINAL
# British NORP
# Richard ODell PERSON
# house ORG
# October DATE
# Poulde GPE
# Feb 4 DATE
# Reuters ORG
# 8.82% PERCENT
# 40,611.4 MONEY
# 2202 DATE
# Friday DATE
# 3,291.29 MONEY
# Bitcoin PERSON
# 23.2% PERCENT
# TIME ORG
# weekly DATE
# Vita ORG

# %% [markdown]
# ---
